# %% [markdown]
# # <font color='blue'>Controls, Financial Reports, KPIs and Analytics</font>

# %% [markdown]
# #### No matter what software is used for your problem, your data will be protected and will provide the answers you’re looking for.

# %% [markdown]
# ![title](imagep/Gemini_Generated_Image_7skxx7skxx7skxx7.png)

# %% [markdown]
#  _________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## <font color="grey">All your controls in the palm of your hand.</font>

# %% [markdown]
# ![tilte](imagep/Image_Analysis-Excel.PNG)

# %% [markdown]
# ## <font color="grey">Reports, Simple or Complex.</font>

# %% [markdown]
# #### _On Microsft Excel_

# %% [markdown]
# ![title](imagep/Image_report.PNG)

# %% [markdown]
# _________________________________

# %% [markdown]
# ## <font color="grey">_Or track everything online._</font>

# %% [markdown]
# ##### <font color="red">Click to watch 👇</font>

# %% [markdown]
# [![title](imagep/IGP.PNG)](https://www.youtube.com/watch?v=1xvDsFCjr3U)

# %% [markdown]
# ____________________________________

# %% [markdown]
# ## <span style="background: linear-gradient(90deg, #1e3a8a, #06b6d4);-webkit-background-clip: text;-webkit-text-fill-color: transparent;font-style: italic;">Customized in the best way for your business.</span>

# %% [markdown]
# ##### <font color="red">Click to watch 👇</font>

# %% [markdown]
# [![title](imagep/gtn.PNG)](https://www.youtube.com/watch?v=oGC8QNRPnyY)

# %% [markdown]
# ______________________________________

# %% [markdown]
#    ###  [[ Let’s Discuss Your Data Needs ]](http://elvisrock.github.io/)

# %% [markdown]
# Author: [Elvis](http://elvisrock.github.io/)
